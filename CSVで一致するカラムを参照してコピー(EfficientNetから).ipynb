# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/grav_bootcamp/blob/master/CSV%E3%81%A7%E4%B8%80%E8%87%B4%E3%81%99%E3%82%8B%E3%82%AB%E3%83%A9%E3%83%A0%E3%82%92%E5%8F%82%E7%85%A7%E3%81%97%E3%81%A6%E3%82%B3%E3%83%94%E3%83%BC(EfficientNet%E3%81%8B%E3%82%89).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

def openCSV(csv_path):
    df = pd.read_csv(csv_path)
    df = df.drop(df.columns[[0]], axis=1) #1列目を削除する
    print(df)
    return df

#CSVを開く （csv1:編集するファイル、csv2:参照するファイル）
csv1_path = '/content/drive/My Drive/Grav_bootcamp/Posttrain_result_2.csv'
csv2_path = '/content/drive/My Drive/Grav_bootcamp/Posttrain_model_eval.csv'

df1, df2 = openCSV(csv1_path), openCSV(csv2_path) #CSVを開く
# Out:
#      image_name Label  Nakagawa kitaguchi inoue kohzaki EfficientNet
# 0            57  grav       NaN      grav  grav    grav         grav
# 1            66  cont       NaN      cont  cont    cont         cont
# 2           118  cont       NaN      cont  cont    cont         cont
# 3           122  grav       NaN      grav  grav    cont         grav
# 4           132  cont       NaN      grav  cont    grav         grav
# 5           149  cont       NaN      cont  cont    cont         cont
# 6           229  cont       NaN      cont  cont    cont         cont
# 7           259  cont       NaN      cont  cont    cont         cont
# 8           385  grav       NaN      grav  cont    grav         cont
# 9           513  cont       NaN      cont  cont    cont         cont
# 10          555  grav       NaN      grav  grav    grav         grav
# 11          782  grav       NaN      grav  grav    grav         cont
# 12          806  cont       NaN      cont  cont    cont         cont
# 13          818  grav       NaN      grav  grav    grav         grav
# 14          861  cont       NaN      cont  cont    cont         cont
# 15          969  cont       NaN      cont  cont    cont         cont
# 16         1079  cont       NaN      cont  cont    cont         cont
# 17         1094  cont       NaN      cont  cont    cont         cont
# 18         1284  grav       NaN      grav  grav    grav         grav
# 19         1336  grav       NaN      grav  grav    grav         grav
# 20         1378  grav       NaN      cont  cont    cont         grav
# 21         1381  cont       NaN      cont  cont    cont         cont
# 22         1413  cont       NaN      cont  cont    cont         cont
# 23         1457  grav       NaN      grav  grav    cont         cont
# 24         1525  grav       NaN      cont  cont    grav         grav
# 25         1768  cont       NaN      cont  cont    cont         cont
# 26         1773  grav       NaN      grav  cont    grav         cont
# 27         1786  grav       NaN      grav  grav    grav         grav
# 28         1805  cont       NaN      cont  cont    cont         cont
# 29         1841  grav       NaN      cont  grav    grav         grav
# 30         1976  grav       NaN      grav  cont    grav         grav
# 31         1994  cont       NaN      cont  cont    cont         cont
# 32         2164  cont       NaN      cont  cont    cont         cont
# 33         2169  cont       NaN      grav  cont    grav         grav
# 34         2366  cont       NaN      cont  cont    cont         cont
# 35         2371  cont       NaN      cont  cont    cont         cont
# 36         2377  cont       NaN      cont  cont    cont         cont
# 37         2384  cont       NaN      cont  cont    cont         cont
# 38         2607  cont       NaN      cont  cont    cont         cont
# 39         2684  grav       NaN      grav  cont    grav         cont
# 40         2726  grav       NaN      grav  cont    grav         grav
# 41         2762  grav       NaN      grav  grav    grav         grav
# 42         2853  grav       NaN      grav  cont    grav         grav
# 43         2969  cont       NaN      cont  cont    cont         grav
# 44         3039  cont       NaN      cont  cont    grav         cont
# 45         3144  grav       NaN      grav  grav    grav         grav
# 46         3193  cont       NaN      cont  cont    cont         cont
# 47         3209  grav       NaN      grav  grav    grav         grav
# 48         3331  grav       NaN      grav  grav    grav         grav
# 49         3511  grav       NaN      grav  cont    grav         grav
# 50         3543  grav       NaN      grav  grav    grav         grav
# 51         3588  cont       NaN      cont  cont    cont         cont
# 52         3663  cont       NaN      cont  cont    cont         cont
# 53         3695  grav       NaN      grav  grav    grav         grav
# 54         4135  cont       NaN      cont  cont    cont         grav
# 55         4292  grav       NaN      grav  grav    grav         grav
# 56         4355  cont       NaN      cont  cont    cont         grav
# 57         4372  cont       NaN      grav  cont    cont         grav
# 58         4386  cont       NaN      cont  cont    cont         cont
# 59         4456  cont       NaN      cont  cont    cont         cont
# 60         4486  grav       NaN      cont  cont    grav         cont
# 61         4540  grav       NaN      grav  grav    grav         grav
# 62         4813  grav       NaN      grav  grav    grav         grav
# 63         4817  cont       NaN      cont  cont    cont         cont
# 64         4835  cont       NaN      cont  cont    cont         cont
# 65         4947  cont       NaN      cont  cont    cont         cont
# 66         4997  grav       NaN      cont  cont    cont         cont
# 67         5015  grav       NaN      cont  cont    grav         grav
# 68         5069  grav       NaN      grav  grav    grav         grav
# 69         5214  cont       NaN      cont  cont    cont         cont
# 70         5281  cont       NaN      cont  cont    cont         cont
# 71         5299  grav       NaN      cont  cont    cont         cont
# 72         5302  cont       NaN      cont  cont    cont         cont
# 73         5335  grav       NaN      grav  cont    cont         cont
# 74         5378  grav       NaN      grav  grav    grav         grav
# 75         5466  cont       NaN      cont  cont    cont         cont
# 76         5481  cont       NaN      cont  cont    cont         cont
# 77         5551  grav       NaN      grav  grav    grav         cont
# 78         5586  grav       NaN      grav  cont    grav         grav
# 79         5599  cont       NaN      cont  cont    cont         cont
# 80         5608  grav       NaN      grav  grav    grav         grav
# 81         5646  grav       NaN      grav  grav    grav         grav
# 82         5714  cont       NaN      cont  cont    cont         cont
# 83         5749  cont       NaN      cont  cont    cont         cont
# 84         5758  grav       NaN      grav  cont    grav         grav
# 85         5763  grav       NaN      grav  grav    grav         grav
# 86         5838  grav       NaN      grav  grav    grav         cont
# 87         5989  grav       NaN      grav  grav    grav         grav
# 88         6003  grav       NaN      grav  cont    cont         grav
# 89         6060  cont       NaN      grav  cont    cont         grav
# 90         6297  grav       NaN      grav  cont    grav         grav
# 91         6361  cont       NaN      cont  cont    cont         cont
# 92         6502  grav       NaN      grav  grav    grav         grav
# 93         6513  grav       NaN      grav  cont    grav         grav
# 94         6706  cont       NaN      cont  cont    cont         cont
# 95         6855  grav       NaN      cont  cont    cont         cont
# 96         6888  cont       NaN      cont  cont    cont         cont
# 97         6913  cont       NaN      cont  grav    cont         cont
# 98         7044  grav       NaN      grav  grav    grav         grav
# 99         7193  cont       NaN      cont  cont    cont         cont
# 100        7302  grav       NaN      grav  cont    cont         grav
# 101        7428  grav       NaN      grav  grav    grav         grav
# 102        7466  cont       NaN      cont  cont    cont         cont
# 103        7726  cont       NaN      cont  cont    cont         cont
# 104        7745  grav       NaN      grav  grav    grav         cont
# 105        7763  grav       NaN      grav  cont    grav         grav
# 106        8079  grav       NaN      grav  grav    grav         grav
# 107        8120  cont       NaN      cont  cont    cont         cont
#      image_name Label EfficientNet    model_prob
# 0            57  grav         grav  9.258354e-01
# 1            66  cont         cont  7.884502e-04
# 2           118  cont         cont  2.690900e-01
# 3           122  grav         cont  8.569366e-02
# 4           132  cont         grav  9.555702e-01
# 5           149  cont         cont  9.100437e-04
# 6           229  cont         cont  2.801418e-05
# 7           259  cont         cont  8.583069e-06
# 8           385  grav         grav  8.831959e-01
# 9           513  cont         cont  1.088381e-04
# 10          555  grav         grav  9.188477e-01
# 11          782  grav         grav  9.992259e-01
# 12          806  cont         cont  2.264977e-06
# 13          818  grav         grav  9.999962e-01
# 14          861  cont         cont  1.394749e-05
# 15          969  cont         cont  1.120704e-02
# 16         1079  cont         cont  3.031492e-04
# 17         1094  cont         cont  1.611710e-04
# 18         1284  grav         grav  9.998980e-01
# 19         1336  grav         cont  2.025205e-01
# 20         1378  grav         grav  9.982185e-01
# 21         1381  cont         cont  3.388636e-01
# 22         1413  cont         cont  2.384186e-07
# 23         1457  grav         cont  5.296290e-03
# 24         1525  grav         grav  9.582633e-01
# 25         1768  cont         cont  1.549721e-06
# 26         1773  grav         grav  9.949269e-01
# 27         1786  grav         grav  9.996216e-01
# 28         1805  cont         cont  1.054108e-03
# 29         1841  grav         cont  1.480389e-02
# 30         1976  grav         cont  1.703761e-01
# 31         1994  cont         cont  3.898144e-05
# 32         2164  cont         cont  2.492070e-04
# 33         2169  cont         grav  9.427994e-01
# 34         2366  cont         cont  3.516674e-05
# 35         2371  cont         cont  1.080036e-04
# 36         2377  cont         cont  2.944469e-05
# 37         2384  cont         cont  1.141214e-01
# 38         2607  cont         cont  1.087666e-03
# 39         2684  grav         cont  2.670288e-05
# 40         2726  grav         grav  9.924778e-01
# 41         2762  grav         grav  9.999999e-01
# 42         2853  grav         grav  9.444281e-01
# 43         2969  cont         grav  7.616358e-01
# 44         3039  cont         cont  4.887044e-03
# 45         3144  grav         grav  9.998690e-01
# 46         3193  cont         cont  2.188760e-02
# 47         3209  grav         grav  9.926319e-01
# 48         3331  grav         grav  9.981179e-01
# 49         3511  grav         grav  1.000000e+00
# 50         3543  grav         grav  9.983760e-01
# 51         3588  cont         cont  2.774596e-04
# 52         3663  cont         cont  2.294230e-02
# 53         3695  grav         grav  9.978544e-01
# 54         4135  cont         grav  8.417434e-01
# 55         4292  grav         grav  9.855990e-01
# 56         4355  cont         cont  4.595602e-02
# 57         4372  cont         cont  6.486905e-02
# 58         4386  cont         cont  5.793571e-05
# 59         4456  cont         cont  1.263618e-05
# 60         4486  grav         cont  2.442575e-01
# 61         4540  grav         grav  9.999390e-01
# 62         4813  grav         grav  9.918813e-01
# 63         4817  cont         cont  6.175041e-05
# 64         4835  cont         cont  1.970947e-03
# 65         4947  cont         cont  2.631545e-04
# 66         4997  grav         cont  9.082556e-04
# 67         5015  grav         grav  9.999959e-01
# 68         5069  grav         grav  9.500477e-01
# 69         5214  cont         cont  3.087521e-05
# 70         5281  cont         cont  3.337860e-06
# 71         5299  grav         cont  5.684495e-04
# 72         5302  cont         cont  4.196167e-05
# 73         5335  grav         cont  2.484715e-02
# 74         5378  grav         grav  9.998196e-01
# 75         5466  cont         cont  9.047985e-05
# 76         5481  cont         cont  1.306236e-03
# 77         5551  grav         cont  2.246094e-02
# 78         5586  grav         grav  9.721628e-01
# 79         5599  cont         cont  6.552339e-04
# 80         5608  grav         grav  9.999801e-01
# 81         5646  grav         grav  1.000000e+00
# 82         5714  cont         grav  5.760909e-01
# 83         5749  cont         grav  5.168937e-01
# 84         5758  grav         grav  9.999114e-01
# 85         5763  grav         grav  9.997070e-01
# 86         5838  grav         cont  1.323223e-05
# 87         5989  grav         grav  9.999710e-01
# 88         6003  grav         grav  9.990491e-01
# 89         6060  cont         cont  4.864931e-04
# 90         6297  grav         grav  9.999489e-01
# 91         6361  cont         cont  4.675388e-04
# 92         6502  grav         grav  9.991006e-01
# 93         6513  grav         grav  9.926387e-01
# 94         6706  cont         cont  1.850182e-02
# 95         6855  grav         cont  2.061427e-02
# 96         6888  cont         cont  5.960464e-07
# 97         6913  cont         cont  5.972385e-04
# 98         7044  grav         grav  9.087099e-01
# 99         7193  cont         cont  8.344650e-06
# 100        7302  grav         grav  9.997131e-01
# 101        7428  grav         grav  9.885085e-01
# 102        7466  cont         cont  1.763701e-03
# 103        7726  cont         cont  5.269051e-05
# 104        7745  grav         grav  9.029746e-01
# 105        7763  grav         grav  9.999627e-01
# 106        8079  grav         grav  9.995499e-01
# 107        8120  cont         cont  2.205372e-05

# %%
def transpose_value(df1, df2, col1, col2):
    k=0
    for i in range(len(df1)):
        img_num = df1.iloc[k,0]  #CSV1つ目の画像番号を取得
        pred = df2[df2['image_name'] == img_num].iloc[0,col2]   #この画像番号に対応する２つ目CSVの行（の●列目）の値を取得
        df1.iloc[k, col1] = pred #CSV1つ目の所定の場所に代入
        k+=1
    return df1

#1つ目CSVと2つ目CSVとの列対応を入力
col1, col2 = 6, 2 #EfficientNet
df1 = transpose_value(df1, df2, col1, col2)

print(df1)
# Out:
#      image_name Label  Nakagawa kitaguchi inoue kohzaki EfficientNet
# 0            57  grav       NaN      grav  grav    grav         grav
# 1            66  cont       NaN      cont  cont    cont         cont
# 2           118  cont       NaN      cont  cont    cont         cont
# 3           122  grav       NaN      grav  grav    cont         cont
# 4           132  cont       NaN      grav  cont    grav         grav
# 5           149  cont       NaN      cont  cont    cont         cont
# 6           229  cont       NaN      cont  cont    cont         cont
# 7           259  cont       NaN      cont  cont    cont         cont
# 8           385  grav       NaN      grav  cont    grav         grav
# 9           513  cont       NaN      cont  cont    cont         cont
# 10          555  grav       NaN      grav  grav    grav         grav
# 11          782  grav       NaN      grav  grav    grav         grav
# 12          806  cont       NaN      cont  cont    cont         cont
# 13          818  grav       NaN      grav  grav    grav         grav
# 14          861  cont       NaN      cont  cont    cont         cont
# 15          969  cont       NaN      cont  cont    cont         cont
# 16         1079  cont       NaN      cont  cont    cont         cont
# 17         1094  cont       NaN      cont  cont    cont         cont
# 18         1284  grav       NaN      grav  grav    grav         grav
# 19         1336  grav       NaN      grav  grav    grav         cont
# 20         1378  grav       NaN      cont  cont    cont         grav
# 21         1381  cont       NaN      cont  cont    cont         cont
# 22         1413  cont       NaN      cont  cont    cont         cont
# 23         1457  grav       NaN      grav  grav    cont         cont
# 24         1525  grav       NaN      cont  cont    grav         grav
# 25         1768  cont       NaN      cont  cont    cont         cont
# 26         1773  grav       NaN      grav  cont    grav         grav
# 27         1786  grav       NaN      grav  grav    grav         grav
# 28         1805  cont       NaN      cont  cont    cont         cont
# 29         1841  grav       NaN      cont  grav    grav         cont
# 30         1976  grav       NaN      grav  cont    grav         cont
# 31         1994  cont       NaN      cont  cont    cont         cont
# 32         2164  cont       NaN      cont  cont    cont         cont
# 33         2169  cont       NaN      grav  cont    grav         grav
# 34         2366  cont       NaN      cont  cont    cont         cont
# 35         2371  cont       NaN      cont  cont    cont         cont
# 36         2377  cont       NaN      cont  cont    cont         cont
# 37         2384  cont       NaN      cont  cont    cont         cont
# 38         2607  cont       NaN      cont  cont    cont         cont
# 39         2684  grav       NaN      grav  cont    grav         cont
# 40         2726  grav       NaN      grav  cont    grav         grav
# 41         2762  grav       NaN      grav  grav    grav         grav
# 42         2853  grav       NaN      grav  cont    grav         grav
# 43         2969  cont       NaN      cont  cont    cont         grav
# 44         3039  cont       NaN      cont  cont    grav         cont
# 45         3144  grav       NaN      grav  grav    grav         grav
# 46         3193  cont       NaN      cont  cont    cont         cont
# 47         3209  grav       NaN      grav  grav    grav         grav
# 48         3331  grav       NaN      grav  grav    grav         grav
# 49         3511  grav       NaN      grav  cont    grav         grav
# 50         3543  grav       NaN      grav  grav    grav         grav
# 51         3588  cont       NaN      cont  cont    cont         cont
# 52         3663  cont       NaN      cont  cont    cont         cont
# 53         3695  grav       NaN      grav  grav    grav         grav
# 54         4135  cont       NaN      cont  cont    cont         grav
# 55         4292  grav       NaN      grav  grav    grav         grav
# 56         4355  cont       NaN      cont  cont    cont         cont
# 57         4372  cont       NaN      grav  cont    cont         cont
# 58         4386  cont       NaN      cont  cont    cont         cont
# 59         4456  cont       NaN      cont  cont    cont         cont
# 60         4486  grav       NaN      cont  cont    grav         cont
# 61         4540  grav       NaN      grav  grav    grav         grav
# 62         4813  grav       NaN      grav  grav    grav         grav
# 63         4817  cont       NaN      cont  cont    cont         cont
# 64         4835  cont       NaN      cont  cont    cont         cont
# 65         4947  cont       NaN      cont  cont    cont         cont
# 66         4997  grav       NaN      cont  cont    cont         cont
# 67         5015  grav       NaN      cont  cont    grav         grav
# 68         5069  grav       NaN      grav  grav    grav         grav
# 69         5214  cont       NaN      cont  cont    cont         cont
# 70         5281  cont       NaN      cont  cont    cont         cont
# 71         5299  grav       NaN      cont  cont    cont         cont
# 72         5302  cont       NaN      cont  cont    cont         cont
# 73         5335  grav       NaN      grav  cont    cont         cont
# 74         5378  grav       NaN      grav  grav    grav         grav
# 75         5466  cont       NaN      cont  cont    cont         cont
# 76         5481  cont       NaN      cont  cont    cont         cont
# 77         5551  grav       NaN      grav  grav    grav         cont
# 78         5586  grav       NaN      grav  cont    grav         grav
# 79         5599  cont       NaN      cont  cont    cont         cont
# 80         5608  grav       NaN      grav  grav    grav         grav
# 81         5646  grav       NaN      grav  grav    grav         grav
# 82         5714  cont       NaN      cont  cont    cont         grav
# 83         5749  cont       NaN      cont  cont    cont         grav
# 84         5758  grav       NaN      grav  cont    grav         grav
# 85         5763  grav       NaN      grav  grav    grav         grav
# 86         5838  grav       NaN      grav  grav    grav         cont
# 87         5989  grav       NaN      grav  grav    grav         grav
# 88         6003  grav       NaN      grav  cont    cont         grav
# 89         6060  cont       NaN      grav  cont    cont         cont
# 90         6297  grav       NaN      grav  cont    grav         grav
# 91         6361  cont       NaN      cont  cont    cont         cont
# 92         6502  grav       NaN      grav  grav    grav         grav
# 93         6513  grav       NaN      grav  cont    grav         grav
# 94         6706  cont       NaN      cont  cont    cont         cont
# 95         6855  grav       NaN      cont  cont    cont         cont
# 96         6888  cont       NaN      cont  cont    cont         cont
# 97         6913  cont       NaN      cont  grav    cont         cont
# 98         7044  grav       NaN      grav  grav    grav         grav
# 99         7193  cont       NaN      cont  cont    cont         cont
# 100        7302  grav       NaN      grav  cont    cont         grav
# 101        7428  grav       NaN      grav  grav    grav         grav
# 102        7466  cont       NaN      cont  cont    cont         cont
# 103        7726  cont       NaN      cont  cont    cont         cont
# 104        7745  grav       NaN      grav  grav    grav         grav
# 105        7763  grav       NaN      grav  cont    grav         grav
# 106        8079  grav       NaN      grav  grav    grav         grav
# 107        8120  cont       NaN      cont  cont    cont         cont

# %% [markdown]
# #**CSVとして保存**

# %%
csv_path = '/content/drive/My Drive/Grav_bootcamp/Posttrain_result.csv'
csv = df1.to_csv(csv_path)
